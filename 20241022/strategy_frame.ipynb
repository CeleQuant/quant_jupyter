# %%
# 量化策略的流程
# 1 导入数据 （包括加载数据和更新数据）
# 2 数据标准化和分析 （数据处理，数据分析）
# 3 交易信号（什么时候买，什么时候卖）
# 4 头寸管理 （什么时候多头（加仓），空头（减仓），以及平仓，仓位管理能很好地止损止盈，降低风险）
# 5 订单管理 （包括下单，撤单，记录订单）
# 6 回测 （回测指标）
# 7 小批量实盘  （实践）
# 8 大额实盘  （实践）

# 当前建立一个简单的框架 当前仅仅支持对一个现货进行交易
# 1 导入数据 
# 2 数据合成15min bar 和 dollar bar，采用2个做比较
# 3 交易信号，先采用简单双均线
# 4 头寸管理， 当前采用全仓
# 5 订单管理
# 6 回测

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px


# 简单框架实现，不使用主流的backtrader，vectorbt之类的框架
class SimpleFrame():
    df = pd.DataFrame()
    orders = pd.DataFrame()

    def __init__(self, data: pd.DataFrame):
        self.df = data

    def resample_data(self, rule='15min'):
        data = self.df
        res_data = data.set_index('datetime')
        res_df = pd.DataFrame()
        res_df['open'] = res_data['open'].resample(rule).first()
        res_df['high'] = res_data['high'].resample(rule).max()
        res_df['low'] = res_data['low'].resample(rule).min()
        res_df['close'] = res_data['close'].resample(rule).last()
        res_df['volume'] = res_data['volume'].resample(rule).sum()
        res_df['amount'] = res_data['amount'].resample(rule).sum()
        res_df['buy_amount'] = res_data['buy_amount'].resample(rule).sum()
        res_df['amount'] = res_data['amount'].resample(rule).sum()
        self.df = res_df
        return self

    def dollar_bar(self):
        data = self.df
        m = data.amount.sum() / (len(data)) * 15
        merge_data = []
        start_index = 0
        current_amount = 0
        for i in range(len(data)):
            current_amount += data.iloc[i]['amount']
            if current_amount >= m:
                bar_data = {
                    'datetime': data.iloc[start_index]['datetime'],
                    'open': data.iloc[start_index]['open'],
                    'close': data.iloc[i]['close'],
                    'high': data.iloc[start_index:i + 1]['high'].max(),
                    'low': data.iloc[start_index:i + 1]['low'].min(),
                    'volume': data.iloc[start_index:i + 1]['amount'].sum(),
                    'buy_amount': data.iloc[start_index:i + 1]['buy_amount'].sum(),
                    'amount': current_amount,
                    'count': i - start_index + 1
                }
                merge_data.append(bar_data)
                start_index = i + 1
                current_amount = 0
        #
        self.df = pd.DataFrame(merge_data)
        return self

    def signal_ma(self, N1=5, N2=20):
        entry_list = {}
        exit_list = {}
        res_df = pd.DataFrame()
        res_df['o'] = self.df['open']
        res_df['h'] = self.df['high']
        res_df['l'] = self.df['low']
        res_df['c'] = self.df['close']
        res_df['v'] = self.df['volume']
        res_df['date'] = self.df.index
        res_df['ma_s'] = res_df['c'].rolling(N1, min_periods=1).mean()
        res_df['ma_l'] = res_df['c'].rolling(N2, min_periods=1).mean()
        last_ma_s = 0
        last_ma_l = 0
        # 默认等交易数据N2天以后再交易
        for i, (index, row) in enumerate(res_df.iterrows()):
            entry_list[index] = False
            exit_list[index] = False
            if i == N1:
                last_ma_s = row['ma_s']
            if i == N2:
                last_ma_l = row['ma_l']
            if i > N2:
                if (row['ma_s'] >= row['ma_l']) and (last_ma_s < last_ma_l):
                    entry_list[index] = True
                if (row['ma_s'] <= row['ma_l']) and (last_ma_s > last_ma_l):
                    exit_list[index] = True
                last_ma_s = row['ma_s']
                last_ma_l = row['ma_l']
        #
        res_df['entry'] = entry_list.values()
        res_df['exit'] = exit_list.values()
        self.df = res_df
        return self

    def create_orders(self, init_cash=100, fee=0.001, slider=0):
        order_list = []
        equity_list = {}
        now_cash = init_cash
        hold_num = 0
        for i, (index, row) in enumerate(self.df.iterrows()):
            equity_list[index] = hold_num * row['c'] + now_cash
            # buy
            if hold_num == 0 and row['entry']:
                # total = price * num + price*num*fee
                trade_num = now_cash /(1+fee)/ (row['c'] + slider)
                trade_fee = (row['c'] + slider) * trade_num * 0.001
                order = {
                    'datetime': index,
                    'price': row['c'] + slider,
                    'side': 'BUY',
                    'fee': trade_fee,
                    'trade_num': trade_num,
                    'pre_pos': hold_num,
                    'pos': trade_num,
                    'pre_cash': now_cash,
                    'cash': 0,
                    'equity': row['c'] * trade_num,
                }
                hold_num = trade_num
                now_cash = 0
                equity_list[index] = hold_num * row['c'] + now_cash
                order_list.append(order)
            #sell
            if hold_num > 0 and row['exit']:
                sell_cash = hold_num * row['c']
                fee_cash = sell_cash * fee
                order = {
                    'datetime': index,
                    'price': row['c'],
                    'side': 'SELL',
                    'fee': fee_cash,
                    'trade_num': hold_num,
                    'pre_pos': hold_num,
                    'pos': 0,
                    'pre_cash': 0,
                    'cash': sell_cash - fee_cash,
                    'equity': sell_cash - fee_cash 
                }
                hold_num = 0
                now_cash = sell_cash - fee_cash
                equity_list[index] = hold_num * row['c'] + now_cash
                order_list.append(order)
        #
        self.orders = pd.DataFrame(order_list)
        self.df['equity'] = equity_list.values()
        return self
    
    def print_indicates(self):
        res_df = self.df.copy()
        pre_max = res_df["equity"].cummax()
        res_df['drawdown'] = res_df['equity'] / pre_max - 1
        indicates = {}
        trade_days = pd.Series([res_df['date'].head(1).values[0],res_df['date'].tail(1).values[0]]).diff()[1]
        indicates['Start'] = pd.to_datetime(res_df['date'].head(1).values[0])
        indicates['End'] = pd.to_datetime(res_df['date'].tail(1).values[0])
        indicates['Period'] = str(trade_days)
        indicates['Start Value'] = 100
        indicates['End Value'] = round(res_df['equity'].tail(1).values[0],4)
        indicates['Max Value'] = round(res_df['equity'].max(),4)
        indicates['Min Value'] = round(res_df['equity'].min(),4)
        indicates['Total Return [%]'] = round(res_df['equity'].tail(1).values[0] - 100,2)
        indicates['Total Fees Paid'] = round(self.orders['fee'].sum(),4)
        indicates['Max Drawdown [%]'] = round(res_df['drawdown'].min()*100,2)
        indicates['Max Drawdown Date'] = res_df['drawdown'].idxmin().strftime('%Y-%m-%d %H:%M:%S')
        indicates['Total Trades'] = len(self.orders)
        indicates['Total Buy Trades'] = len(self.orders.loc[self.orders['side'] == 'BUY'])
        indicates['Total Sell Trades'] = len(self.orders.loc[self.orders['side'] == 'SELL'])
        for k,v in indicates.items():
            print("%-30s        %s" % (k, v))
    
    def show_plotly(self):
        orders_df = self.orders.copy()
        res_df = self.df.copy()
        buy_df = orders_df.loc[orders_df['entry'] == True]
        sell_df = orders_df.loc[orders_df['exit'] == True]
        fig = go.Figure(layout=go.Layout(width=1200, height=600))
        fig.add_candlestick(
            name='kline',
            x=res_df.index,
            open=res_df['o'],
            high=res_df['h'],
            low=res_df['l'],
            close=res_df['c']
        )
        fig.data[0].increasing.fillcolor = 'green'
        fig.data[0].increasing.line.color = 'green'
        fig.data[0].decreasing.fillcolor = 'red'
        fig.data[0].decreasing.line.color = 'red'
        #添加MA_S MA_L
        fig.add_scatter(x=res_df.index, y=res_df['ma_s'], mode='lines', line=dict(color='blue', width=1), name="MA_S")
        fig.add_scatter(x=res_df.index, y=res_df['ma_l'], mode='lines', line=dict(color='orange', width=1), name="MA_L")
        # 添加交易点
        fig.add_scatter(x=buy_df.index, y=buy_df['c'], mode='markers', name='buy', marker=dict(size=10, symbol="diamond"))
        fig.add_scatter(x=sell_df.index, y=sell_df['c'], mode='markers', name='sell', marker=dict(size=10, symbol="diamond"))
        fig.update(layout_xaxis_rangeslider_visible=False)
        fig.show()

# %%
data = pd.read_csv('../20241020/BTCUSDT.csv', parse_dates=['datetime'])
# data = data[:]

# %%
SF = SimpleFrame(data)
SF = SF.resample_data('1h').signal_ma()
SF.df
# Out:
#                             o         h         l         c           v  \
# datetime
# 2023-01-01 00:00:00  16590.10  16613.30  16581.24  16600.39  4269.58976
# 2023-01-01 01:00:00  16600.93  16604.37  16571.01  16582.08  4844.04845
# 2023-01-01 02:00:00  16581.45  16589.36  16571.80  16577.79  3340.80330
# 2023-01-01 03:00:00  16577.78  16590.06  16565.10  16570.14  4044.43359
# 2023-01-01 04:00:00  16570.14  16574.97  16564.09  16568.60  2622.14355
# ...                       ...       ...       ...       ...         ...
# 2024-10-01 12:00:00  63723.47  63879.81  63652.06  63868.94   778.75286
# 2024-10-01 13:00:00  63868.93  63899.99  63674.49  63749.99   816.29206
# 2024-10-01 14:00:00  63750.00  64097.03  63750.00  64033.98   778.17242
# 2024-10-01 15:00:00  64033.99  64130.63  63920.00  64045.92  1142.17634
# 2024-10-01 16:00:00  64045.92  64096.00  63925.23  63958.00   641.85613
#
#                                    date          ma_s          ma_l  entry  \
# datetime
# 2023-01-01 00:00:00 2023-01-01 00:00:00  16600.390000  16600.390000  False
# 2023-01-01 01:00:00 2023-01-01 01:00:00  16591.235000  16591.235000  False
# 2023-01-01 02:00:00 2023-01-01 02:00:00  16586.753333  16586.753333  False
# 2023-01-01 03:00:00 2023-01-01 03:00:00  16582.600000  16582.600000  False
# 2023-01-01 04:00:00 2023-01-01 04:00:00  16579.800000  16579.800000  False
# ...                                 ...           ...           ...    ...
# 2024-10-01 12:00:00 2024-10-01 12:00:00  63605.234000  63629.265000  False
# 2024-10-01 13:00:00 2024-10-01 13:00:00  63648.834000  63639.714000   True
# 2024-10-01 14:00:00 2024-10-01 14:00:00  63764.030000  63659.113500  False
# 2024-10-01 15:00:00 2024-10-01 15:00:00  63884.462000  63670.437500  False
# 2024-10-01 16:00:00 2024-10-01 16:00:00  63931.366000  63665.937500  False
#
#                       exit
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                        123.428688
# Max Drawdown [%]                        36.754103
# Max Drawdown Duration           350 days 20:00:00
# Total Trades                                  516
# Total Closed Trades                           515
# Total Open Trades                               1
# Open Trade PnL                            0.24367
# Win Rate [%]                            28.932039
# Best Trade [%]                          18.606155
# Worst Trade [%]                         -5.696785
# Avg Winning Trade [%]                     2.29763
# Avg Losing Trade [%]                    -0.878548
# Avg Winning Trade Duration        1 days 06:07:14
# Avg Losing Trade Duration         0 days 09:44:15
# Profit Factor                             1.01987
# Expectancy                               0.015122
# Sharpe Ratio                             0.301173
# Calmar Ratio                             0.122611
# Omega Ratio                               1.01431
# Sortino Ratio                            0.443838
# dtype: object

# %%
pf.orders.records_readable
# Out:
#       Order Id  Column           Timestamp      Size     Price      Fees  Side
# 0            0       0 2023-01-03 15:00:00  0.005971  16729.74  0.099900   Buy
# 1            1       0 2023-01-03 22:00:00  0.005971  16661.23  0.099491  Sell
# 2            2       0 2023-01-04 10:00:00  0.005933  16736.52  0.099292   Buy
# 3            3       0 2023-01-05 06:00:00  0.005933  16826.68  0.099827  Sell
# 4            4       0 2023-01-06 02:00:00  0.005915  16841.93  0.099628   Buy
# ...        ...     ...                 ...       ...       ...       ...   ...
# 1026      1026       0 2024-09-29 07:00:00  0.001676  65858.00  0.110388   Buy
# 1027      1027       0 2024-09-29 15:00:00  0.001676  65477.01  0.109750  Sell
# 1028      1028       0 2024-09-29 23:00:00  0.001666  65751.34  0.109531   Buy
# 1029      1029       0 2024-09-30 09:00:00  0.001666  64769.99  0.107896  Sell
# 1030      1030       0 2024-10-01 13:00:00  0.001689  63749.99  0.107680   Buy
#
# [1031 rows x 7 columns]

# %%
pf.cash()
# Out:
# datetime
# 2023-01-01 00:00:00    100.000000
# 2023-01-01 01:00:00    100.000000
# 2023-01-01 02:00:00    100.000000
# 2023-01-01 03:00:00    100.000000
# 2023-01-01 04:00:00    100.000000
#                           ...
# 2024-10-01 12:00:00    107.787915
# 2024-10-01 13:00:00      0.000000
# 2024-10-01 14:00:00      0.000000
# 2024-10-01 15:00:00      0.000000
# 2024-10-01 16:00:00      0.000000
# Freq: h, Length: 15353, dtype: float64

# %%
res_orders = pf.orders.records_readable
equity_list = {}
cash_list = {}
last_equity = 100
for i, (index, row) in enumerate(res_orders.iterrows()):
    if row['Side']=='Buy':
        equity_list[index] = row['Price']*row['Size']
        cash_list[index] = 0
    if row['Side']=='Sell':
        equity_list[index] = row['Price']*row['Size'] - row['Fees']
        cash_list[index] = equity_list[index]
    last_equity = equity_list[index]
    #
res_orders['Cash'] = cash_list.values()
res_orders['Equity'] = equity_list.values()
res_orders
# Out:
#       Order Id  Column           Timestamp      Size     Price      Fees  \
# 0            0       0 2023-01-03 15:00:00  0.005971  16729.74  0.099900
# 1            1       0 2023-01-03 22:00:00  0.005971  16661.23  0.099491
# 2            2       0 2023-01-04 10:00:00  0.005933  16736.52  0.099292
# 3            3       0 2023-01-05 06:00:00  0.005933  16826.68  0.099827
# 4            4       0 2023-01-06 02:00:00  0.005915  16841.93  0.099628
# ...        ...     ...                 ...       ...       ...       ...
# 1026      1026       0 2024-09-29 07:00:00  0.001676  65858.00  0.110388
# 1027      1027       0 2024-09-29 15:00:00  0.001676  65477.01  0.109750
# 1028      1028       0 2024-09-29 23:00:00  0.001666  65751.34  0.109531
# 1029      1029       0 2024-09-30 09:00:00  0.001666  64769.99  0.107896
# 1030      1030       0 2024-10-01 13:00:00  0.001689  63749.99  0.107680
#
#       Side        Cash      Equity
# 0      Buy    0.000000   99.900100
# 1     Sell   99.391508   99.391508
# 2      Buy    0.000000   99.292216
# 3     Sell   99.727278   99.727278
# 4      Buy    0.000000   99.627650
# ...    ...         ...         ...
# 1026   Buy    0.000000  110.388454
# 1027  Sell  109.640104  109.640104
# 1028   Buy    0.000000  109.530573
# 1029  Sell  107.787915  107.787915
# 1030   Buy    0.000000  107.680235
#
# [1031 rows x 9 columns]

# %%
SF.orders
# Out:
#                 datetime     price  side       fee  trade_num   pre_pos  \
# 0    2023-01-03 15:00:00  16729.74   BUY  0.099900   0.005971  0.000000
# 1    2023-01-03 22:00:00  16661.23  SELL  0.099491   0.005971  0.005971
# 2    2023-01-04 10:00:00  16736.52   BUY  0.099292   0.005933  0.000000
# 3    2023-01-05 06:00:00  16826.68  SELL  0.099827   0.005933  0.005933
# 4    2023-01-06 02:00:00  16841.93   BUY  0.099628   0.005915  0.000000
# ...                  ...       ...   ...       ...        ...       ...
# 1026 2024-09-29 07:00:00  65858.00   BUY  0.110388   0.001676  0.000000
# 1027 2024-09-29 15:00:00  65477.01  SELL  0.109750   0.001676  0.001676
# 1028 2024-09-29 23:00:00  65751.34   BUY  0.109531   0.001666  0.000000
# 1029 2024-09-30 09:00:00  64769.99  SELL  0.107896   0.001666  0.001666
# 1030 2024-10-01 13:00:00  63749.99   BUY  0.107680   0.001689  0.000000
#
#            pos    pre_cash        cash      equity
# 0     0.005971  100.000000    0.000000   99.900100
# 1     0.000000    0.000000   99.391508   99.391508
# 2     0.005933   99.391508    0.000000   99.292216
# 3     0.000000    0.000000   99.727278   99.727278
# 4     0.005915   99.727278    0.000000   99.627650
# ...        ...         ...         ...         ...
# 1026  0.001676  110.498842    0.000000  110.388454
# 1027  0.000000    0.000000  109.640104  109.640104
# 1028  0.001666  109.640104    0.000000  109.530573
# 1029  0.000000    0.000000  107.787915  107.787915
# 1030  0.001689  107.787915    0.000000  107.680235
#
# [1031 rows x 10 columns]

# %%
pf.plot()
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '36a8e4b3-d0cc-4c0e-a271-0633686f3104',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([16600.39, 16582.08, 16577.79, ..., 64033.98, 64045.92, 63958.  ]),
#               'yaxis': 'y'},
#              {'customdata': array([[0.00000000e+00, 5.97140780e-03, 9.99000999e-02],
#                                    [2.00000000e+00, 5.93266793e-03, 9.92922155e-02],
#                                    [4.00000000e+00, 5.91545328e-03, 9.96276501e-02],
#                                    ...,
#                                    [1.02600000e+03, 1.67615861e-03, 1.10388454e-01],
#                                    [1.02800000e+03, 1.66583028e-03, 1.09530573e-01],
#                                    [1.03000000e+03, 1.68910199e-03, 1.07680235e-01]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': '4a45eb17-9ed9-4aa1-b09d-67adef69c918',
#               'x': array([datetime.datetime(2023, 1, 3, 15, 0),
#                           datetime.datetime(2023, 1, 4, 10, 0),
#                           datetime.datetime(2023, 1, 6, 2, 0), ...,
#                           datetime.datetime(2024, 9, 29, 7, 0),
#                           datetime.datetime(2024, 9, 29, 23, 0),
#                           datetime.datetime(2024, 10, 1, 13, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([16729.74, 16736.52, 16841.93, ..., 65858.  , 65751.34, 63749.99]),
#               'yaxis': 'y'},
#              {'customdata': array([[1.00000000e+00, 5.97140780e-03, 9.94909988e-02],
#                                    [3.00000000e+00, 5.93266793e-03, 9.98271049e-02],
#                                    [5.00000000e+00, 5.91545328e-03, 9.94398345e-02],
#                                    ...,
#                                    [1.02500000e+03, 1.68519745e-03, 1.10609451e-01],
#                                    [1.02700000e+03, 1.67615861e-03, 1.09749854e-01],
#                                    [1.02900000e+03, 1.66583028e-03, 1.07895811e-01]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': 'fd3c848f-d3a9-4cce-8c78-f80d4d3bc033',
#               'x': array([datetime.datetime(2023, 1, 3, 22, 0),
#                           datetime.datetime(2023, 1, 5, 6, 0),
#                           datetime.datetime(2023, 1, 6, 13, 0), ...,
#                           datetime.datetime(2024, 9, 28, 16, 0),
#                           datetime.datetime(2024, 9, 29, 15, 0),
#                           datetime.datetime(2024, 9, 30, 9, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([16661.23, 16826.68, 16810.18, ..., 65635.9 , 65477.01, 64769.99]),
#               'yaxis': 'y'},
#              {'customdata': array([[1.00000000e+00, 1.00000000e+00, 3.35770021e-01, 3.38163489e-03],
#                                    [3.00000000e+00, 3.00000000e+00, 1.88013734e-01, 1.89451380e-03],
#                                    [6.00000000e+00, 6.00000000e+00, 1.05309798e+00, 1.06689328e-02],
#                                    ...,
#                                    [5.08000000e+02, 5.08000000e+02, 4.60968736e+00, 4.45666946e-02],
#                                    [5.10000000e+02, 5.10000000e+02, 5.01223356e-02, 4.64284357e-04],
#                                    [5.12000000e+02, 5.12000000e+02, 3.00818298e+00, 2.80135148e-02]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': array([0.75271971, 0.75152076, 0.75859487, 0.75587539, 0.89557283, 0.75114449,
#                                            0.75107034, 0.81075207, 0.75702248, 0.76356754, 0.75248805, 0.75606518,
#                                            0.75353573, 0.7615737 , 0.81212595, 0.76136207, 0.75747976, 0.75218918,
#                                            0.9       , 0.83769894, 0.75604825, 0.75075378, 0.76057724, 0.75193728,
#                                            0.77654555, 0.75079245, 0.75310429, 0.79037043, 0.75281935, 0.76321203,
#                                            0.75218872, 0.77929373, 0.75576388, 0.75473881, 0.75223391, 0.76238933,
#                                            0.75271783, 0.75341622, 0.75793493, 0.75739944, 0.78374134, 0.75051524,
#                                            0.76266499, 0.76347688, 0.76962029, 0.75581218, 0.8407893 , 0.75966546,
#                                            0.75402151, 0.75017341, 0.75010216, 0.7529703 , 0.75486558, 0.76445829,
#                                            0.75009789, 0.75371907, 0.75717674, 0.75596187, 0.75334269, 0.76260569,
#                                            0.75162238, 0.76511374, 0.75363111, 0.75024436, 0.75563694, 0.79325215,
#                                            0.78124872, 0.75411943, 0.84641952, 0.76195873, 0.75698774, 0.75167953,
#                                            0.77057766, 0.77934402, 0.76327479, 0.7602355 , 0.7562449 , 0.76461793,
#                                            0.76523675, 0.80546027, 0.77840386, 0.75018843, 0.77673592, 0.76761316,
#                                            0.763504  , 0.75963696, 0.79485924, 0.75595579, 0.79454667, 0.75405722,
#                                            0.77497841, 0.75865717, 0.76360983, 0.75175082, 0.82468748, 0.76169046,
),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': '084cde76-08a5-4e9d-8092-3d8ccd0e5dc1',
#               'x': array([datetime.datetime(2023, 1, 5, 6, 0),
#                           datetime.datetime(2023, 1, 7, 20, 0),
#                           datetime.datetime(2023, 1, 10, 7, 0),
#                           datetime.datetime(2023, 1, 11, 21, 0),
#                           datetime.datetime(2023, 1, 15, 2, 0),
#                           datetime.datetime(2023, 1, 18, 10, 0),
#                           datetime.datetime(2023, 1, 20, 16, 0),
#                           datetime.datetime(2023, 1, 22, 9, 0),
#                           datetime.datetime(2023, 1, 26, 19, 0),
#                           datetime.datetime(2023, 1, 30, 16, 0),
#                           datetime.datetime(2023, 2, 1, 16, 0),
#                           datetime.datetime(2023, 2, 2, 22, 0),
#                           datetime.datetime(2023, 2, 8, 19, 0),
#                           datetime.datetime(2023, 2, 15, 16, 0),
#                           datetime.datetime(2023, 2, 17, 6, 0),
#                           datetime.datetime(2023, 2, 18, 19, 0),
#                           datetime.datetime(2023, 2, 27, 16, 0),
#                           datetime.datetime(2023, 3, 9, 4, 0),
#                           datetime.datetime(2023, 3, 15, 6, 0),
#                           datetime.datetime(2023, 3, 19, 1, 0),
#                           datetime.datetime(2023, 3, 20, 12, 0),
#                           datetime.datetime(2023, 3, 22, 19, 0),
#                           datetime.datetime(2023, 3, 24, 17, 0),
#                           datetime.datetime(2023, 3, 27, 13, 0),
#                           datetime.datetime(2023, 3, 30, 23, 0),
#                           datetime.datetime(2023, 4, 5, 22, 0),
#                           datetime.datetime(2023, 4, 10, 22, 0),
#                           datetime.datetime(2023, 4, 12, 11, 0),
#                           datetime.datetime(2023, 4, 14, 23, 0),
#                           datetime.datetime(2023, 4, 19, 13, 0),
#                           datetime.datetime(2023, 4, 23, 20, 0),
#                           datetime.datetime(2023, 4, 27, 5, 0),
#                           datetime.datetime(2023, 4, 28, 17, 0),
#                           datetime.datetime(2023, 5, 3, 20, 0),
#                           datetime.datetime(2023, 5, 6, 14, 0),
#                           datetime.datetime(2023, 5, 16, 6, 0),
#                           datetime.datetime(2023, 5, 18, 22, 0),
#                           datetime.datetime(2023, 5, 21, 17, 0),
#                           datetime.datetime(2023, 5, 24, 3, 0),
#                           datetime.datetime(2023, 5, 27, 17, 0),
#                           datetime.datetime(2023, 5, 29, 21, 0),
#                           datetime.datetime(2023, 6, 3, 18, 0),
#                           datetime.datetime(2023, 6, 7, 17, 0),
#                           datetime.datetime(2023, 6, 16, 22, 0),
#                           datetime.datetime(2023, 6, 18, 2, 0),
#                           datetime.datetime(2023, 6, 20, 22, 0),
#                           datetime.datetime(2023, 6, 22, 18, 0),
#                           datetime.datetime(2023, 6, 24, 15, 0),
#                           datetime.datetime(2023, 6, 30, 7, 0),
#                           datetime.datetime(2023, 7, 2, 12, 0),
#                           datetime.datetime(2023, 7, 3, 21, 0),
#                           datetime.datetime(2023, 7, 4, 15, 0),
#                           datetime.datetime(2023, 7, 11, 19, 0),
#                           datetime.datetime(2023, 7, 14, 17, 0),
#                           datetime.datetime(2023, 7, 22, 15, 0),
#                           datetime.datetime(2023, 8, 2, 20, 0),
#                           datetime.datetime(2023, 8, 10, 1, 0),
#                           datetime.datetime(2023, 8, 24, 20, 0),
#                           datetime.datetime(2023, 9, 13, 8, 0),
#                           datetime.datetime(2023, 9, 15, 17, 0),
#                           datetime.datetime(2023, 9, 19, 4, 0),
#                           datetime.datetime(2023, 9, 29, 20, 0),
#                           datetime.datetime(2023, 10, 2, 3, 0),
#                           datetime.datetime(2023, 10, 6, 1, 0),
#                           datetime.datetime(2023, 10, 8, 3, 0),
#                           datetime.datetime(2023, 10, 17, 15, 0),
#                           datetime.datetime(2023, 10, 21, 10, 0),
#                           datetime.datetime(2023, 10, 22, 11, 0),
#                           datetime.datetime(2023, 10, 25, 1, 0),
#                           datetime.datetime(2023, 10, 26, 16, 0),
#                           datetime.datetime(2023, 11, 2, 21, 0),
#                           datetime.datetime(2023, 11, 5, 22, 0),
#                           datetime.datetime(2023, 11, 10, 3, 0),
#                           datetime.datetime(2023, 11, 16, 19, 0),
#                           datetime.datetime(2023, 11, 21, 15, 0),
#                           datetime.datetime(2023, 11, 23, 22, 0),
#                           datetime.datetime(2023, 11, 25, 16, 0),
#                           datetime.datetime(2023, 11, 29, 23, 0),
#                           datetime.datetime(2023, 12, 2, 19, 0),
#                           datetime.datetime(2023, 12, 5, 15, 0),
#                           datetime.datetime(2023, 12, 7, 6, 0),
#                           datetime.datetime(2023, 12, 9, 17, 0),
#                           datetime.datetime(2023, 12, 14, 23, 0),
#                           datetime.datetime(2023, 12, 19, 23, 0),
#                           datetime.datetime(2023, 12, 21, 13, 0),
#                           datetime.datetime(2023, 12, 28, 15, 0),
#                           datetime.datetime(2024, 1, 3, 2, 0),
#                           datetime.datetime(2024, 1, 5, 12, 0),
#                           datetime.datetime(2024, 1, 9, 19, 0),
#                           datetime.datetime(2024, 1, 16, 2, 0),
#                           datetime.datetime(2024, 1, 27, 16, 0),
#                           datetime.datetime(2024, 1, 29, 0, 0),
#                           datetime.datetime(2024, 1, 31, 7, 0),
#                           datetime.datetime(2024, 2, 2, 21, 0),
#                           datetime.datetime(2024, 2, 10, 15, 0),
#                           datetime.datetime(2024, 2, 12, 6, 0),
#                           datetime.datetime(2024, 2, 16, 3, 0),
#                           datetime.datetime(2024, 2, 20, 0, 0),
#                           datetime.datetime(2024, 2, 26, 0, 0),
#                           datetime.datetime(2024, 3, 1, 2, 0),
#                           datetime.datetime(2024, 3, 5, 16, 0),
#                           datetime.datetime(2024, 3, 8, 10, 0),
#                           datetime.datetime(2024, 3, 9, 19, 0),
#                           datetime.datetime(2024, 3, 11, 4, 0),
#                           datetime.datetime(2024, 3, 12, 12, 0),
#                           datetime.datetime(2024, 3, 14, 10, 0),
#                           datetime.datetime(2024, 3, 18, 19, 0),
#                           datetime.datetime(2024, 3, 21, 21, 0),
#                           datetime.datetime(2024, 3, 27, 0, 0),
#                           datetime.datetime(2024, 3, 29, 10, 0),
#                           datetime.datetime(2024, 4, 5, 13, 0),
#                           datetime.datetime(2024, 4, 8, 5, 0),
#                           datetime.datetime(2024, 4, 9, 9, 0),
#                           datetime.datetime(2024, 4, 11, 21, 0),
#                           datetime.datetime(2024, 4, 23, 15, 0),
#                           datetime.datetime(2024, 4, 28, 22, 0),
#                           datetime.datetime(2024, 5, 3, 18, 0),
#                           datetime.datetime(2024, 5, 5, 10, 0),
#                           datetime.datetime(2024, 5, 7, 23, 0),
#                           datetime.datetime(2024, 5, 14, 10, 0),
#                           datetime.datetime(2024, 5, 17, 0, 0),
#                           datetime.datetime(2024, 5, 18, 23, 0),
#                           datetime.datetime(2024, 5, 21, 23, 0),
#                           datetime.datetime(2024, 5, 26, 12, 0),
#                           datetime.datetime(2024, 5, 31, 13, 0),
#                           datetime.datetime(2024, 6, 4, 7, 0),
#                           datetime.datetime(2024, 6, 6, 11, 0),
#                           datetime.datetime(2024, 6, 13, 6, 0),
#                           datetime.datetime(2024, 6, 26, 15, 0),
#                           datetime.datetime(2024, 6, 28, 15, 0),
#                           datetime.datetime(2024, 7, 1, 21, 0),
#                           datetime.datetime(2024, 7, 7, 15, 0),
#                           datetime.datetime(2024, 7, 10, 22, 0),
#                           datetime.datetime(2024, 7, 16, 16, 0),
#                           datetime.datetime(2024, 7, 20, 17, 0),
#                           datetime.datetime(2024, 7, 28, 7, 0),
#                           datetime.datetime(2024, 8, 7, 23, 0),
#                           datetime.datetime(2024, 8, 9, 20, 0),
#                           datetime.datetime(2024, 8, 14, 21, 0),
#                           datetime.datetime(2024, 8, 19, 3, 0),
#                           datetime.datetime(2024, 8, 22, 23, 0),
#                           datetime.datetime(2024, 8, 25, 5, 0),
#                           datetime.datetime(2024, 9, 3, 20, 0),
#                           datetime.datetime(2024, 9, 10, 23, 0),
#                           datetime.datetime(2024, 9, 14, 18, 0),
#                           datetime.datetime(2024, 9, 18, 17, 0),
#                           datetime.datetime(2024, 9, 20, 22, 0),
#                           datetime.datetime(2024, 9, 23, 20, 0),
#                           datetime.datetime(2024, 9, 28, 16, 0)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([3.38163489e-03, 1.89451380e-03, 1.06689328e-02, 7.29580262e-03,
#                           1.80570286e-01, 1.42780617e-03, 1.33583168e-03, 7.53623977e-02,
#                           8.71859953e-03, 1.68368075e-02, 3.09430175e-03, 7.53121420e-03,
#                           4.39379727e-03, 1.43637293e-02, 7.70664881e-02, 1.41012445e-02,
#                           9.28579957e-03, 2.72358999e-03, 1.86061551e-01, 1.08786093e-01,
#                           7.51021791e-03, 9.43188566e-04, 1.31277715e-02, 2.41114269e-03,
#                           3.29341449e-02, 9.91156727e-04, 3.85865766e-03, 5.00819139e-02,
#                           3.50523225e-03, 1.63958507e-02, 2.72301918e-03, 3.63428713e-02,
#                           7.15749108e-03, 5.88604738e-03, 2.77907568e-03, 1.53754082e-02,
#                           3.37930195e-03, 4.24556449e-03, 9.85036838e-03, 9.18617328e-03,
#                           4.18594846e-02, 6.47316212e-04, 1.57173193e-02, 1.67243568e-02,
),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': 'bd28a26b-55f1-429c-82cd-981ca1f1a1b3',
#               'x': array([datetime.datetime(2023, 1, 3, 22, 0),
#                           datetime.datetime(2023, 1, 6, 13, 0),
#                           datetime.datetime(2023, 1, 8, 20, 0), ...,
#                           datetime.datetime(2024, 9, 25, 17, 0),
#                           datetime.datetime(2024, 9, 29, 15, 0),
#                           datetime.datetime(2024, 9, 30, 9, 0)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([-0.00609101, -0.00388329, -0.00329814, ..., -0.00577314, -0.00777924,
#                           -0.01691025]),
#               'yaxis': 'y2'},
#              {'customdata': array([[5.15000000e+02, 5.15000000e+02, 2.43669870e-01, 2.26290247e-03]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '5',
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'opacity': array([0.75181776]),
#                          'size': array([7.08482884]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Open',
#               'type': 'scatter',
#               'uid': 'f766ff1f-27df-406f-89e3-023fb86d2745',
#               'x': array([datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([0.0022629]),
#               'yaxis': 'y2'},
#              {'legendgroup': '6',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'dae6062d-6583-42a1-a62b-a6bb19aa60fc',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 0.99889701, 0.99863859, ..., 3.85737805, 3.85809731,
#                           3.85280105]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '64bdd479-2506-423b-940b-2068413fd260',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7bcb5565-253d-4046-9d67-3c931f3026a5',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.08159923, 1.08180091,
#                           1.08031585]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bba3fb56-bd12-4938-8660-36e3432c80db',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '35e133f3-87e0-4755-9b03-3819c4325c0f',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([1., 1., 1., ..., 1., 1., 1.]),
#               'yaxis': 'y3'},
#              {'legendgroup': '8',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3d597e56-953e-4bbe-98aa-9816617d1344',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.08159923, 1.08180091,
#                           1.08031585]),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '7',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd35f9022-4c37-45c5-8da5-ccd7c9bd4936',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 2, 0), ...,
#                           datetime.datetime(2024, 10, 1, 14, 0),
#                           datetime.datetime(2024, 10, 1, 15, 0),
#                           datetime.datetime(2024, 10, 1, 16, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })

# %%
SF.print_indicates()
# Out:
# Start                                 2023-01-01 00:00:00
# End                                   2024-10-01 16:00:00
# Period                                639 days 16:00:00
# Start Value                           100
# End Value                             108.0316
# Max Value                             155.8387
# Min Value                             98.5616
# Total Return [%]                      8.03
# Total Fees Paid                       123.4287
# Max Drawdown [%]                      -36.75
# Max Drawdown Date                     2024-09-09 05:00:00
# Total Trades                          1031
# Total Buy Trades                      516
# Total Sell Trades                     515

# %%
pf.stats()
# Out:
# Start                         2023-01-01 00:00:00
# End                           2024-10-01 16:00:00
# Period                          639 days 17:00:00
# Start Value                                 100.0
# End Value                              108.031585
# Total Return [%]                         8.031585
# Benchmark Return [%]                   285.280105
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                        123.428688
# Max Drawdown [%]                        36.754103
# Max Drawdown Duration           350 days 20:00:00
# Total Trades                                  516
# Total Closed Trades                           515
# Total Open Trades                               1
# Open Trade PnL                            0.24367
# Win Rate [%]                            28.932039
# Best Trade [%]                          18.606155
# Worst Trade [%]                         -5.696785
# Avg Winning Trade [%]                     2.29763
# Avg Losing Trade [%]                    -0.878548
# Avg Winning Trade Duration        1 days 06:07:14
# Avg Losing Trade Duration         0 days 09:44:15
# Profit Factor                             1.01987
# Expectancy                               0.015122
# Sharpe Ratio                             0.301173
# Calmar Ratio                             0.122611
# Omega Ratio                               1.01431
# Sortino Ratio                            0.443838
# dtype: object
